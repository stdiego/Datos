# %%
import pandas as pd
from IPython.core.pylabtools import figsize
from jupyterlab_server.process import which
from matplotlib.lines import lineStyles

# %%
df= pd.read_csv('C:/Users/diego/Desktop/cursos/tiendas_procesado.csv')
df
# Out:
#       fecha      DAIRY          MEATS       SEAFOOD
# 0   2015-01  1134521.0  543117.728891  40465.835012
# 1   2015-02  1020747.0  498735.076839  36066.561003
# 2   2015-03  1234851.0  546517.159221  43808.473074
# 3   2015-04  1181180.0  522304.280744  39983.471003
# 4   2015-05  1293308.0  591691.899734  42506.832015
# 5   2015-06  1243588.0  565014.130035  38780.552004
# 6   2015-07  1244815.0  594903.677368  38535.588006
# 7   2015-08  1263428.0  581214.143026  37767.580998
# 8   2015-09  1224619.0  562711.633157  41906.374010
# 9   2015-10  1314827.0  580788.361242  41423.962963
# 10  2015-11  1283672.0  535908.927954  38823.761011
# 11  2015-12  1394582.0  567381.391078  33728.276973

# %%
df.plot.line(
    figsize = (10, 5)
)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use(
    'bmh'
)
df.plot.line(
    figsize = (10, 5)
)
ax=df.plot.line(
    figsize = (10, 5)
)
ax.xaxis.grid(
    color='blue',
    alpha=0.5,
    linewidth=1,
)
ax.xaxis.grid(
    visible=False,
)
ax.yaxis.grid(
    color='red',
    alpha=0.5,

)

# %%
import seaborn as sns

# %%
plt.figure (
    figsize = (10, 5)
)
sns.set_style('whitegrid')
sns.set_theme('talk')
sns.lineplot(
    data=df,
)
ax=sns.
# Out:
# <Axes: >

# %%
import plotly.express as px

# %%
fig= px.line(
    df,
    width=800,
    height=600,
    template='plotly_dark',
)
fig.update_xaxes(showgrid=False)
fig.update_yaxes(
    gridwidth=1,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 fig= px.line(
#       2     df,
#       3     width=800,
#       4     height=600,
#       5     template='plotly_dark',
#       6 )
#       7 fig.update_xaxes(showgrid=False)
#       8 fig.update_yaxes(
#       9     gridwidth=1,
#      10 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_chart_types.py:270, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, subtitle, template, width, height)
#     221 def line(
#     222     data_frame=None,
#     223     x=None,
#    (...)    264     height=None,
#     265 ) -> go.Figure:
#     266     """
#     267     In a 2D line plot, each row of `data_frame` is represented as a vertex of
#     268     a polyline mark in 2D space.
#     269     """
# --> 270     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_core.py:2491, in make_figure(args, constructor, trace_patch, layout_patch)
#    2488 layout_patch = layout_patch or {}
#    2489 apply_default_cascade(args)
# -> 2491 args = build_dataframe(args, constructor)
#    2492 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2493     args = process_dataframe_hierarchy(args)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_core.py:1789, in build_dataframe(args, constructor)
#    1787         dtype = v_dtype
#    1788     elif dtype != v_dtype:
# -> 1789         raise ValueError(
#    1790             "Plotly Express cannot process wide-form data with columns of different type."
#    1791         )
#    1792 df_output = df_output.unpivot(
#    1793     index=wide_id_vars,
#    1794     on=wide_value_vars,
#    1795     variable_name=var_name,
#    1796     value_name=value_name,
#    1797 )
#    1798 assert len(df_output.columns) == len(set(df_output.columns)), (
#    1799     "Wide-mode name-inference failure, likely due to a internal bug. "
#    1800     "Please report this to "
#    1801     "https://github.com/plotly/plotly.py/issues/new and we will try to "
#    1802     "replicate and fix it."
#    1803 )
#
# ValueError: Plotly Express cannot process wide-form data with columns of different type.
